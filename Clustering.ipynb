# %% [markdown]
# **Clustering based on PCA result**

# %%
import pandas as pd
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
from matplotlib.cm import get_cmap
from sklearn.metrics import silhouette_score, calinski_harabasz_score, davies_bouldin_score

import numpy as np

# %%
# Load PCA and AE data
df_pca = pd.read_csv("./PCA/car_price_pca.csv")
df_ae = pd.read_csv("./AE/car_price_ae.csv") 
df_sae = pd.read_csv("./SAE/car_price_sae.csv")

# Function to perform clustering and visualization
def cluster_and_visualize(data, name, x_col, y_col):
    ks = range(2, 15)
    sil_scores = []
    db_scores = []  # Davies-Bouldin scores
    inertias = []   # Elbow method scores
    score_dict = {}
    
    # Calculate multiple metrics for each k
    for k in ks:
        km = KMeans(n_clusters=k, random_state=42)
        labels = km.fit_predict(data)
        
        # Silhouette score (higher is better)
        sil = silhouette_score(data, labels)
        sil_scores.append(sil)
        
        # Davies-Bouldin score (lower is better)
        db = davies_bouldin_score(data, labels)
        db_scores.append(db)
        
        # Inertia for elbow method (lower is better)
        inertias.append(km.inertia_)
        
        print(f"{name} - k = {k}:")
        print(f"  Silhouette Score = {sil:.4f}")
        print(f"  Davies-Bouldin Score = {db:.4f}")
        print(f"  Inertia = {km.inertia_:.4f}")
        score_dict[k] = sil, db, km.inertia_


    # Normalize scores to 0-1 range for comparison
    norm_sil = (sil_scores - np.min(sil_scores)) / (np.max(sil_scores) - np.min(sil_scores))
    norm_db = 1 - (db_scores - np.min(db_scores)) / (np.max(db_scores) - np.min(db_scores))  # Invert DB score
    norm_inertia = 1 - (inertias - np.min(inertias)) / (np.max(inertias) - np.min(inertias))  # Invert inertia
    
    # Combined score (weighted average)
    combined_scores = 0.4 * norm_sil + 0.3 * norm_db + 0.3 * norm_inertia

    # Visualize all metrics
    fig, ((ax1, ax2), (ax3, ax4)) = plt.subplots(2, 2, figsize=(15, 10))
    
    ax1.plot(list(ks), sil_scores, marker='o')
    ax1.set_xlabel("Number of clusters (k)")
    ax1.set_ylabel("Silhouette Score")
    ax1.set_title("Silhouette Analysis")
    ax1.grid(True)
    
    ax2.plot(list(ks), db_scores, marker='o')
    ax2.set_xlabel("Number of clusters (k)")
    ax2.set_ylabel("Davies-Bouldin Score")
    ax2.set_title("Davies-Bouldin Analysis")
    ax2.grid(True)
    
    ax3.plot(list(ks), inertias, marker='o')
    ax3.set_xlabel("Number of clusters (k)")
    ax3.set_ylabel("Inertia")
    ax3.set_title("Elbow Method")
    ax3.grid(True)
    
    ax4.plot(list(ks), combined_scores, marker='o')
    ax4.set_xlabel("Number of clusters (k)")
    ax4.set_ylabel("Combined Score")
    ax4.set_title("Combined Metric")
    ax4.grid(True)
    
    plt.tight_layout()
    plt.savefig(f"{name}/clustering_metrics_{name.lower()}.png", dpi=300)
    plt.show()

    optimal_k = ks[np.argmax(combined_scores)]
    print(f"\n{name} - Optimal k from combined metrics: {optimal_k}")
    print(score_dict[optimal_k])
    
    # Assess cluster stability
    n_runs = 5
    stability_scores = []
    for _ in range(n_runs):
        kmeans = KMeans(n_clusters=optimal_k, random_state=np.random.randint(0, 1000))
        labels = kmeans.fit_predict(data)
        stability_scores.append(silhouette_score(data, labels))
    
    print(f"Cluster stability (std of silhouette scores across {n_runs} runs): {np.std(stability_scores):.4f}")

    # Final clustering with optimal k
    kmeans = KMeans(n_clusters=optimal_k, random_state=42)
    data['cluster'] = kmeans.fit_predict(data)

    # Original scatter plot
    plt.figure(figsize=(10, 10))
    cmap = get_cmap("tab10", optimal_k)
    scatter = plt.scatter(
        data[x_col], data[y_col],
        c=data['cluster'], 
        cmap=cmap,
        s=50, alpha=0.8, edgecolors='k'
    )
    
    handles, labels = scatter.legend_elements(prop="colors")
    plt.legend(handles, [f"Cluster {i}" for i in range(optimal_k)],
               title="Clusters", bbox_to_anchor=(1.05, 1), loc='upper left')
    plt.xlabel(x_col)
    plt.ylabel(y_col)
    plt.title(f"K-Means Clustering on {name}-reduced Data")
    plt.tight_layout()
    plt.savefig(f"{name}/kmeans_{name.lower()}_scatter.png", dpi=300)
    plt.show()

    # t-SNE visualization
    tsne_data = TSNE(n_components=2, random_state=42, perplexity=30, n_iter=1000).fit_transform(data.drop(columns=['cluster']))
    
    plt.figure(figsize=(10, 10))
    for i in range(optimal_k):
        mask = data['cluster'] == i
        plt.scatter(tsne_data[mask, 0], tsne_data[mask, 1], label=f'Cluster {i}')
    plt.title(f't-SNE visualization of KMeans clustering - {name}')
    plt.legend()
    plt.savefig(f"{name}/tsne_kmeans_{name.lower()}.png", dpi=300)
    plt.show()
    
    return data['cluster']

# Perform clustering on PCA data
print("Clustering PCA data:")
pca_clusters = cluster_and_visualize(df_pca, "PCA", "PC1", "PC2")

# Perform clustering on AE data  
print("\nClustering AE data:")
ae_clusters = cluster_and_visualize(df_ae, "AE", "AE_1", "AE_2")

# Perform clustering on SAE data  
print("\nClustering SAE data:")
sae_clusters = cluster_and_visualize(df_sae, "SAE", "SAE_1", "SAE_2")
# Out:
# Clustering PCA data:
# PCA - k = 2:
#   Silhouette Score = 0.2285
#   Davies-Bouldin Score = 2.0314
#   Inertia = 9020.7197
# PCA - k = 3:
#   Silhouette Score = 0.2368
#   Davies-Bouldin Score = 1.9186
#   Inertia = 8553.9924
# PCA - k = 4:
#   Silhouette Score = 0.2299
#   Davies-Bouldin Score = 2.0249
#   Inertia = 7828.5213
# PCA - k = 5:
#   Silhouette Score = 0.2106
#   Davies-Bouldin Score = 1.8524
#   Inertia = 7252.7673
# PCA - k = 6:
#   Silhouette Score = 0.2163
#   Davies-Bouldin Score = 1.6530
#   Inertia = 6934.3970
# PCA - k = 7:
#   Silhouette Score = 0.2398
#   Davies-Bouldin Score = 1.4318
#   Inertia = 6257.5941
# PCA - k = 8:
#   Silhouette Score = 0.2009
#   Davies-Bouldin Score = 1.4514
#   Inertia = 5328.7564
# PCA - k = 9:
#   Silhouette Score = 0.2416
#   Davies-Bouldin Score = 1.3667
#   Inertia = 4899.6272
# PCA - k = 10:
#   Silhouette Score = 0.2580
#   Davies-Bouldin Score = 1.3077
#   Inertia = 4565.1316
# PCA - k = 11:
#   Silhouette Score = 0.2672
#   Davies-Bouldin Score = 1.2595
#   Inertia = 4272.0930
# PCA - k = 12:
#   Silhouette Score = 0.2750
#   Davies-Bouldin Score = 1.2267
#   Inertia = 4075.8428
# PCA - k = 13:
#   Silhouette Score = 0.2751
#   Davies-Bouldin Score = 1.1809
#   Inertia = 3957.9164
# PCA - k = 14:
#   Silhouette Score = 0.2786
#   Davies-Bouldin Score = 1.1521
#   Inertia = 3572.1312
# PCA - Optimal k from combined metrics: 14
# (np.float64(0.27860259595573045), np.float64(1.1521033235094051), 3572.1312415036696)
# Cluster stability (std of silhouette scores across 5 runs): 0.0231
# /var/folders/4q/93kk_sns4ks8qydt2mt9nfm80000gn/T/ipykernel_85802/3705180542.py:96: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = get_cmap("tab10", optimal_k)
# /Users/zhengtaohan/miniconda3/envs/workspace/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# Clustering AE data:
# AE - k = 2:
#   Silhouette Score = 0.2041
#   Davies-Bouldin Score = 2.2643
#   Inertia = 31840.3500
# AE - k = 3:
#   Silhouette Score = 0.2002
#   Davies-Bouldin Score = 2.2927
#   Inertia = 29105.7407
# AE - k = 4:
#   Silhouette Score = 0.2079
#   Davies-Bouldin Score = 1.9765
#   Inertia = 27068.3520
# AE - k = 5:
#   Silhouette Score = 0.1144
#   Davies-Bouldin Score = 2.1759
#   Inertia = 25635.1276
# AE - k = 6:
#   Silhouette Score = 0.1075
#   Davies-Bouldin Score = 2.0864
#   Inertia = 24293.6031
# AE - k = 7:
#   Silhouette Score = 0.1250
#   Davies-Bouldin Score = 1.9518
#   Inertia = 22961.5419
# AE - k = 8:
#   Silhouette Score = 0.1458
#   Davies-Bouldin Score = 1.8262
#   Inertia = 22252.0578
# AE - k = 9:
#   Silhouette Score = 0.1485
#   Davies-Bouldin Score = 1.7899
#   Inertia = 21238.9013
# AE - k = 10:
#   Silhouette Score = 0.1550
#   Davies-Bouldin Score = 1.7740
#   Inertia = 20501.2159
# AE - k = 11:
#   Silhouette Score = 0.1661
#   Davies-Bouldin Score = 1.6713
#   Inertia = 19605.2596
# AE - k = 12:
#   Silhouette Score = 0.1777
#   Davies-Bouldin Score = 1.5772
#   Inertia = 18459.0531
# AE - k = 13:
#   Silhouette Score = 0.1753
#   Davies-Bouldin Score = 1.5632
#   Inertia = 17440.7309
# AE - k = 14:
#   Silhouette Score = 0.1838
#   Davies-Bouldin Score = 1.5555
#   Inertia = 16881.0957
# AE - Optimal k from combined metrics: 14
# (np.float64(0.18378270878525432), np.float64(1.5554649629427704), 16881.095675067765)
# Cluster stability (std of silhouette scores across 5 runs): 0.0135
# /var/folders/4q/93kk_sns4ks8qydt2mt9nfm80000gn/T/ipykernel_85802/3705180542.py:96: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = get_cmap("tab10", optimal_k)
# /Users/zhengtaohan/miniconda3/envs/workspace/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(
# Clustering SAE data:
# SAE - k = 2:
#   Silhouette Score = 0.1964
#   Davies-Bouldin Score = 2.4136
#   Inertia = 149874.9400
# SAE - k = 3:
#   Silhouette Score = 0.1377
#   Davies-Bouldin Score = 2.1542
#   Inertia = 135077.9199
# SAE - k = 4:
#   Silhouette Score = 0.1395
#   Davies-Bouldin Score = 2.1584
#   Inertia = 128171.7822
# SAE - k = 5:
#   Silhouette Score = 0.1465
#   Davies-Bouldin Score = 1.8682
#   Inertia = 115594.5061
# SAE - k = 6:
#   Silhouette Score = 0.1523
#   Davies-Bouldin Score = 1.6871
#   Inertia = 108407.6718
# SAE - k = 7:
#   Silhouette Score = 0.1619
#   Davies-Bouldin Score = 1.7422
#   Inertia = 101905.5933
# SAE - k = 8:
#   Silhouette Score = 0.1811
#   Davies-Bouldin Score = 1.6456
#   Inertia = 96856.4988
# SAE - k = 9:
#   Silhouette Score = 0.1993
#   Davies-Bouldin Score = 1.6088
#   Inertia = 90420.0127
# SAE - k = 10:
#   Silhouette Score = 0.2032
#   Davies-Bouldin Score = 1.5418
#   Inertia = 88488.6803
# SAE - k = 11:
#   Silhouette Score = 0.2151
#   Davies-Bouldin Score = 1.4334
#   Inertia = 82850.4924
# SAE - k = 12:
#   Silhouette Score = 0.2148
#   Davies-Bouldin Score = 1.4374
#   Inertia = 76755.4343
# SAE - k = 13:
#   Silhouette Score = 0.2345
#   Davies-Bouldin Score = 1.3852
#   Inertia = 73054.0395
# SAE - k = 14:
#   Silhouette Score = 0.2464
#   Davies-Bouldin Score = 1.3352
#   Inertia = 67907.1530
# SAE - Optimal k from combined metrics: 14
# (np.float64(0.24642874778554508), np.float64(1.3352294629380737), 67907.15295179788)
# Cluster stability (std of silhouette scores across 5 runs): 0.0150
# /var/folders/4q/93kk_sns4ks8qydt2mt9nfm80000gn/T/ipykernel_85802/3705180542.py:96: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = get_cmap("tab10", optimal_k)
# /Users/zhengtaohan/miniconda3/envs/workspace/lib/python3.10/site-packages/sklearn/manifold/_t_sne.py:1164: FutureWarning: 'n_iter' was renamed to 'max_iter' in version 1.5 and will be removed in 1.7.
#   warnings.warn(

# %%
def find_competitors(df_orig, df_clusters, name):
    df_orig['cluster'] = df_clusters['cluster']
    
    vw_cluster = df_orig.loc[df_orig['CarBrand_volkswagen'] == 1, 'cluster'].mode()[0]
    print(f"Cluster number for Volkswagen ({name}): {vw_cluster}")
    
    competitors = df_orig[df_orig['cluster'] == vw_cluster]
    
    competitors.to_csv(f"{name}/vw_competitors_{name.lower()}.csv", index=False)
    print(f"Found {len(competitors)} competitor models for {name}, saved to vw_competitors_{name.lower()}.csv")
    return competitors

df_orig = pd.read_csv("./car_price_preprocessed.csv")
pca_competitors = find_competitors(df_orig.copy(), df_pca, "PCA")

ae_competitors = find_competitors(df_orig.copy(), df_ae, "AE")

sae_competitors = find_competitors(df_orig.copy(), df_sae, "SAE")
# Out:
# Cluster number for Volkswagen (PCA): 4
# Found 59 competitor models for PCA, saved to vw_competitors_pca.csv
# Cluster number for Volkswagen (AE): 9
# Found 13 competitor models for AE, saved to vw_competitors_ae.csv
# Cluster number for Volkswagen (SAE): 2
# Found 28 competitor models for SAE, saved to vw_competitors_sae.csv
